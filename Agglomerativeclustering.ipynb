# %% [markdown]
# <a href="https://colab.research.google.com/github/mishra2arya/Unsuppervised-learning/blob/main/Agglomerativeclustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.metrics import davies_bouldin_score

# %%
X, _ = make_blobs(n_samples=30, centers=3, random_state=42)
labels=AgglomerativeClustering(n_clusters=3, linkage='single').fit_predict(X)
score=davies_bouldin_score(X, labels)

plt.subplot(1,2,1)
dendrogram(linkage(X,'single'))
plt.subplot(1,2,2)
plt.scatter(X[:,0], X[:,1], c=labels)
plt.title(f'Davies-Bouldin Score: {score}')
plt.show()
