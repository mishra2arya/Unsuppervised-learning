# %% [markdown]
# <a href="https://colab.research.google.com/github/mishra2arya/Unsuppervised-learning/blob/main/minibatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
X, _=make_blobs(n_samples=1000, centers =3, n_features=2, random_state=42)
mbk_means = MiniBatchKMeans(n_clusters=3, batch_size=100, random_state=42)
mbk_means.fit(X)
plt.scatter(X[:,0], X[:,1], c=mbk_means.labels_, cmap = 'viridis')
plt.scatter(mbk_means.cluster_centers_[:,0], mbk_means.cluster_centers_[:,1],s=200, c='black', marker='x')
plt.show()
plt.title('MiniBatch K-Means Clustering')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
data=pd.read_csv("/content/mall.zip")

X=data[["Annual Income (k$)", "Spending Score (1-100)"]]
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
kmeans=KMeans(n_clusters=3,
              init="k-means++",
              n_init=10,
              random_state=42)
kmeans.fit(X_scaled)
data["cluster"]=kmeans.labels_
print("Cluster Centers:")
print(kmeans.cluster_centers_)
print(data.head())
plt.figure(figsize=(8,6))
# Out:
# Cluster Centers:
# [[ 1.00919971 -1.22553537]
#  [ 0.99158305  1.23950275]
#  [-0.62618966 -0.01439238]]
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    cluster
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2

# %%
plt.figure(figsize=(8,6))
plt.scatter(
    X_scaled[:,0],
    X_scaled[:,1],
    c=kmeans.labels_,
    s=50
)
